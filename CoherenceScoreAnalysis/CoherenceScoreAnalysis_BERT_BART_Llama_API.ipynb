# %% [markdown]
# #Book Corpus vs BERT

# %%
import pandas as pd

# Read the CSV file into a pandas DataFrame
df = pd.read_csv('/content/filtered_entity_probabilities_statistics_BERT.csv')  # Replace 'your_file.csv' with your actual file path

# Step 2: Convert "average_probability" to a float while preserving the decimal places
#df['average_probability'] = df['average_probability'].apply(lambda x: "{:.50f}".format(x))
df['average_probability'] = df['average_probability'].astype(float)


# Create a dictionary with 'Entity' as keys and 'API Response' as values
entity_api_dict = pd.Series(df['average_probability'].values, index=df['Entity']).to_dict()

# Print the resulting dictionary
print(entity_api_dict)
# Out:
# {'-LSB- -RSB- China': 1.3617827290595928e-25, '-LSB- -RSB- This kind of discarded electronic trash': 6.197162184880156e-36, '1983 Contest': 1.2629439204418916e-05, 'A European diplomatic source': 2.77895603210003e-09, 'A Google departure': 3.809429427276641e-09, 'A Nomad of the Time Streams': 8.738412465456384e-16, 'A Philippine politician whose family was allegedly murdered to stop him running for governor': 4.6132410304406105e-33, 'A Russian diver': 4.015039032962122e-05, 'A big attraction on the Thames': 1.4799178726897695e-11, 'A car': 0.0188094021513399, 'A conversion rate': 6.751120030956136e-05, 'A couple months': 0.0002606698240004, 'A court in Morocco on Monday': 1.656337863098758e-13, 'A culture': 0.006398284317665, 'A department spokesman': 2.0017663407611016e-05, 'A faction from within the disbanded NLD': 5.706459806150257e-17, 'A fifth strikeout': 6.320645292030662e-06, 'A fifth synagogue': 1.9724579165226106e-07, 'A friend': 0.0737491580147807, 'A gigantic robot': 0.0001659906379531, 'A group of Coptic youth': 4.21953923688355e-08, "A helicopter dispatched by China's transport ministry": 1.7920778804114053e-18, 'A lackluster All-Star game for Pujols': 8.345684192954174e-41, 'A modern dial tone': 4.225559385602016e-07, 'A perfectionism': 3.5665676946811803e-06, "A political party registered to run in Myanmar's elections this year": 2.257829974486628e-25, 'A prosecutor': 0.0057996208376667, 'A second Jordanian official': 1.340444670077794e-08, 'A six-month-old girl': 5.387574366086918e-06, 'A sixth person': 0.0001135103363475, "A spokesman for Gulf Canada, which is controlled by Toronto's Reichmann family": 3.3258986521043408e-43, 'A team of US Air Force experts': 2.8335355189816687e-10, 'A top Iranian reformist from a banned political party': 4.736313114424983e-21, 'A year': 0.0084595592771391, 'AARP Insurance Plan American Association': 5.0316003549142476e-15, 'ABC Family': 0.0202700886338102, "ABC's John Martin": 4.4024777673744324e-13, 'ACC referee Ron Cherry': 1.0847752009728184e-14, 'ACT headquarters': 1.135189542997887e-07, 'ARM architecture and List of ARM microprocessor cores': 7.0156216105586274e-31, 'Aba Lujayn': 4.046238643418305e-17, 'Abba-Zabas': 1.5885618193753158e-15, 'Abraham': 0.2535137825499987, 'Aceh governor Irwandi Yusuf': 5.296841637831224e-24, 'Additional Resources The wikipedia': 4.157701827120466e-13, 'Aden': 0.1209630970357508, 'Adkins': 1.357178173303531e-06, 'Administration officials': 0.0001625919135615, 'Aerosmith': 1.5849057751351983e-05, 'Aetna': 3.2258001486084687e-10, 'Afghanistan': 0.0871332740643992, 'Aftershock': 1.6569221707319716e-12, 'Agatharchides': 1.325680815670929e-12, 'Ahmadinejad': 1.5145917374182574e-08, "Ahmose-Henuttamehu's mummy": 3.348336673554886e-37, 'Aizutakada': 8.833754432740984e-12, 'Al Gore': 0.0002231652739207, 'Al-Dhahabi in his Talkhis al-Mustadrak': 1.5553492835926148e-39, 'Alan Bean': 3.641452675469773e-07, 'Alan Cohn and Bobcat Goldthwait (the latter previously worked with Brown in Medusa: Dare to Be Truthful and Shakes the Clown)': 2.0844687165972744e-85, 'Alang': 1.110424623690097e-05, 'Albany County Republican Chairman Joseph C. Frangella': 4.4367100213360655e-25, "Albert Finney in Sidney Lumet's crime drama": 2.198239696699672e-27, 'Alberta Party supporters': 9.91849939262074e-08, 'Aleksandr M. Prokhorov Shared the Nobel Prize in Physics in 1964 for, respectively, semiconductor lasers and': 9.375286677991697e-53, 'Alex Webster': 1.1149778025729285e-06, 'Alex Wharf': 1.9117630489103134e-09, 'Algeria': 0.0392157873196992, 'Ali Duba': 3.1101390510406196e-11, 'Ali Hewson': 1.913626446584396e-16, 'All of their friends': 4.085614059762742e-07, 'All the players': 0.0024251421202083, 'All three men': 0.0003389227533719, 'Amblypygids, particularly the species Phrynus marginemaculatus and Damon diadema': 6.787838465875177e-80, 'American': 0.2552312660496681, 'American Gangster': 0.0009496122863578, 'American Sign Language, or ASL, for a time': 4.62433854209 ...

# %%
import pickle

from scipy.stats import spearmanr, pearsonr, kendalltau

with open('/content/final_combined.pkl', 'rb') as f:  # Replace 'your_pickle_file.pkl' with your pickle file path
    phrase_counter = pickle.load(f)

book_corpus_entities = dict(phrase_counter)

# Step 3: Map the occurrences from the pickle data to the "Entity" column in the DataFrame
# We assume the 'phrase_counter' is a dictionary where the keys are phrases (same as 'Entity' column)
# and the values are their respective counts (or occurrence counts)
df['Book Corpus Count'] = df['Entity'].map(phrase_counter)

# Step 4: Handle missing data if any entities in the CSV don't exist in the phrase_counter
# For example, replace NaN values with 0 or another default value
df['Book Corpus Count'].fillna(0, inplace=True)

# Step 5: Calculate Spearman correlation between the 'API Response' and 'Phrase Count' columns
# Extract the 'API Response' and 'Phrase Count' columns as lists
api_response_values = df['average_probability']
phrase_count_values = df['Book Corpus Count']

spearman_corr, _ = spearmanr(api_response_values, phrase_count_values)
pearson_corr, _ = pearsonr(api_response_values, phrase_count_values)
kendall_corr, _ = kendalltau(api_response_values, phrase_count_values)

# Step 7: Print the correlation coefficients
print(f"Spearman correlation: {spearman_corr}")
print(f"Pearson correlation: {pearson_corr}")
print(f"Kendall correlation: {kendall_corr}")
# Out:
# Spearman correlation: 0.5706135671969552
# Pearson correlation: 0.23324780128452624
# Kendall correlation: 0.46312242751482335
# /tmp/ipython-input-3633331887.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Book Corpus Count'].fillna(0, inplace=True)

# %% [markdown]
# #Book Corpus vs BART

# %%
import pandas as pd

# Read the CSV file into a pandas DataFrame
df = pd.read_csv('/content/filtered_entity_probabilities_statistics_BART.csv')  # Replace 'your_file.csv' with your actual file path

# Step 2: Convert "average_probability" to a float while preserving the decimal places
#df['average_probability'] = df['average_probability'].apply(lambda x: "{:.50f}".format(x))
df['average_probability'] = df['average_probability'].astype(float)


# Create a dictionary with 'Entity' as keys and 'API Response' as values
entity_api_dict = pd.Series(df['average_probability'].values, index=df['Entity']).to_dict()

# Print the resulting dictionary
print(entity_api_dict)
# Out:
# {'-LSB- -RSB- China': 9.168375650185551e-31, '-LSB- -RSB- This kind of discarded electronic trash': 1.0336012288226478e-49, '1983 Contest': 7.048868120173073e-11, 'A European diplomatic source': 3.678502438874193e-06, 'A Google departure': 2.2006337725224413e-07, 'A Nomad of the Time Streams': 2.3139995411410022e-24, 'A Philippine politician whose family was allegedly murdered to stop him running for governor': 6.89962678240069e-28, 'A Russian diver': 8.666463392720231e-10, 'A big attraction on the Thames': 4.767327455146247e-13, 'A car': 0.0012926603441997, 'A conversion rate': 0.0020895493909016, 'A couple months': 4.06641462722582e-05, 'A court in Morocco on Monday': 2.98197696412306e-07, 'A culture': 0.0076351587218798, 'A department spokesman': 2.9455541751335244e-05, 'A faction from within the disbanded NLD': 4.884685673668085e-18, 'A fifth strikeout': 3.1740234344334996e-10, 'A fifth synagogue': 1.6938633643628996e-08, 'A friend': 0.0321100866691423, 'A gigantic robot': 6.714915341296695e-06, 'A group of Coptic youth': 1.9891573709178682e-08, "A helicopter dispatched by China's transport ministry": 1.9453256668553852e-16, 'A lackluster All-Star game for Pujols': 1.1688860403684747e-29, 'A modern dial tone': 1.029380983726257e-07, 'A perfectionism': 1.470731119506434e-07, "A political party registered to run in Myanmar's elections this year": 2.1877392743052656e-18, 'A prosecutor': 0.0002344728152795, 'A second Jordanian official': 3.4923499686016376e-08, 'A six-month-old girl': 2.5667417602647305e-17, 'A sixth person': 1.5380580284928556e-05, "A spokesman for Gulf Canada, which is controlled by Toronto's Reichmann family": 1.669196323480084e-40, 'A team of US Air Force experts': 6.740721415744619e-07, 'A top Iranian reformist from a banned political party': 5.838519238134288e-18, 'A year': 6.591805343682181e-08, 'AARP Insurance Plan American Association': 6.816051639549927e-17, 'ABC Family': 7.798785881219248e-08, "ABC's John Martin": 1.1375449521851663e-14, 'ACC referee Ron Cherry': 7.467319098987693e-15, 'ACT headquarters': 1.303887903194544e-09, 'ARM architecture and List of ARM microprocessor cores': 1.6285351559207578e-22, 'Aba Lujayn': 8.995428546126005e-27, 'Abba-Zabas': 1.5738670082596468e-29, 'Abraham': 0.0049629427989766, 'Aceh governor Irwandi Yusuf': 6.952057243165839e-36, 'Additional Resources The wikipedia': 6.286290200360871e-12, 'Aden': 1.0948376318568087e-14, 'Adkins': 1.3898766794750084e-09, 'Administration officials': 1.5683573951254786e-08, 'Aerosmith': 5.077121752593567e-09, 'Aetna': 6.8291655657935e-08, 'Afghanistan': 0.000291171734656, 'Aftershock': 6.521980811682711e-09, 'Agatharchides': 1.0286525691758294e-17, 'Ahmadinejad': 2.6614788238941467e-11, "Ahmose-Henuttamehu's mummy": 8.909579503084724e-53, 'Aizutakada': 1.4341866750328252e-28, 'Al Gore': 0.0019141085165959, 'Al-Dhahabi in his Talkhis al-Mustadrak': 1.9484201592081777e-57, 'Alan Bean': 8.471470096131281e-05, 'Alan Cohn and Bobcat Goldthwait (the latter previously worked with Brown in Medusa: Dare to Be Truthful and Shakes the Clown)': 1.0864320344915023e-86, 'Alang': 2.4783810097198567e-10, 'Albany County Republican Chairman Joseph C. Frangella': 3.290268609001945e-38, "Albert Finney in Sidney Lumet's crime drama": 9.924200968414936e-20, 'Alberta Party supporters': 1.7483556469826095e-11, 'Aleksandr M. Prokhorov Shared the Nobel Prize in Physics in 1964 for, respectively, semiconductor lasers and': 2.680840345923363e-53, 'Alex Webster': 3.672244880559348e-08, 'Alex Wharf': 3.623044914313352e-11, 'Algeria': 1.6683610509039575e-10, 'Ali Duba': 6.807188778818814e-13, 'Ali Hewson': 2.003462978392918e-12, 'All of their friends': 1.7456697331477714e-09, 'All the players': 0.0007992099291514, 'All three men': 3.017108991088539e-05, 'Amblypygids, particularly the species Phrynus marginemaculatus and Damon diadema': 1.3724814336170025e-109, 'American': 0.012158227851534, 'American Gangster': 1.378501452930822e-06, 'American Sign Language, or AS ...

# %%
import pickle

from scipy.stats import spearmanr, pearsonr, kendalltau

with open('/content/final_combined.pkl', 'rb') as f:  # Replace 'your_pickle_file.pkl' with your pickle file path
    phrase_counter = pickle.load(f)

book_corpus_entities = dict(phrase_counter)

# Step 3: Map the occurrences from the pickle data to the "Entity" column in the DataFrame
# We assume the 'phrase_counter' is a dictionary where the keys are phrases (same as 'Entity' column)
# and the values are their respective counts (or occurrence counts)
df['Book Corpus Count'] = df['Entity'].map(phrase_counter)

# Step 4: Handle missing data if any entities in the CSV don't exist in the phrase_counter
# For example, replace NaN values with 0 or another default value
df['Book Corpus Count'].fillna(0, inplace=True)

# Step 5: Calculate Spearman correlation between the 'API Response' and 'Phrase Count' columns
# Extract the 'API Response' and 'Phrase Count' columns as lists
api_response_values = df['average_probability']
phrase_count_values = df['Book Corpus Count']

spearman_corr, _ = spearmanr(api_response_values, phrase_count_values)
pearson_corr, _ = pearsonr(api_response_values, phrase_count_values)
kendall_corr, _ = kendalltau(api_response_values, phrase_count_values)

# Step 7: Print the correlation coefficients
print(f"Spearman correlation: {spearman_corr}")
print(f"Pearson correlation: {pearson_corr}")
print(f"Kendall correlation: {kendall_corr}")
# Out:
# Spearman correlation: 0.3591229499066282
# Pearson correlation: 0.15778866555663157
# Kendall correlation: 0.27960259890709305
# /tmp/ipython-input-3633331887.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Book Corpus Count'].fillna(0, inplace=True)

# %% [markdown]
# #Book Corpus vs LLAMA

# %%
import pandas as pd

# Read the CSV file into a pandas DataFrame
df = pd.read_csv('/content/filtered_entity_probabilities_statistics_LLAMA.csv')  # Replace 'your_file.csv' with your actual file path

# Step 2: Convert "average_probability" to a float while preserving the decimal places
#df['average_probability'] = df['average_probability'].apply(lambda x: "{:.50f}".format(x))
df['average_probability'] = df['average_probability'].astype(float)


# Create a dictionary with 'Entity' as keys and 'API Response' as values
entity_api_dict = pd.Series(df['average_probability'].values, index=df['Entity']).to_dict()

# Print the resulting dictionary
print(entity_api_dict)
# Out:
# {'-LSB- -RSB- China': 2.3027226861839965e-19, '-LSB- -RSB- This kind of discarded electronic trash': 2.7802449539537922e-34, '1983 Contest': 1.4917642265940342e-09, 'A European diplomatic source': 7.62350994249725e-10, 'A Google departure': 2.8552958287303927e-11, 'A Nomad of the Time Streams': 1.224410406875199e-13, 'A Philippine politician whose family was allegedly murdered to stop him running for governor': 2.248071433729363e-26, 'A Russian diver': 1.644132070851383e-07, 'A big attraction on the Thames': 1.0736811591334095e-13, 'A car': 0.0006694229843207, 'A conversion rate': 5.4962481415693625e-05, 'A couple months': 2.0253051875971206e-07, 'A court in Morocco on Monday': 3.7769207014930856e-14, 'A culture': 3.338098515018747e-05, 'A department spokesman': 2.9256700353851955e-11, 'A faction from within the disbanded NLD': 1.5496098180739036e-15, 'A fifth strikeout': 2.183497591672332e-09, 'A fifth synagogue': 3.810262252620383e-12, 'A friend': 0.0063276128391188, 'A gigantic robot': 4.5561017269612283e-07, 'A group of Coptic youth': 6.222395997975474e-09, "A helicopter dispatched by China's transport ministry": 2.146920960546443e-17, 'A lackluster All-Star game for Pujols': 5.562643911224211e-19, 'A modern dial tone': 1.823072702063136e-11, 'A perfectionism': 3.615381422318399e-06, "A political party registered to run in Myanmar's elections this year": 1.759827279420179e-16, 'A prosecutor': 0.0003229548122647, 'A second Jordanian official': 1.6742358600962218e-11, 'A six-month-old girl': 2.931020271789366e-10, 'A sixth person': 3.1540644129533364e-08, "A spokesman for Gulf Canada, which is controlled by Toronto's Reichmann family": 8.81997402252532e-31, 'A team of US Air Force experts': 6.7878962037225445e-09, 'A top Iranian reformist from a banned political party': 1.2254104942506822e-19, 'A year': 0.0020744420981046, 'AARP Insurance Plan American Association': 7.81112891847711e-14, 'ABC Family': 0.024837264420196, "ABC's John Martin": 5.427110805590142e-14, 'ACC referee Ron Cherry': 3.5780799343158415e-17, 'ACT headquarters': 2.0722485642014543e-11, 'ARM architecture and List of ARM microprocessor cores': 3.196817450929508e-20, 'Aba Lujayn': 1.3618308497428105e-18, 'Abba-Zabas': 3.955486243015944e-14, 'Abraham': 0.0730157836078433, 'Aceh governor Irwandi Yusuf': 1.5448009322303423e-11, 'Additional Resources The wikipedia': 4.09657960188314e-17, 'Aden': 0.0177518007459539, 'Adkins': 2.535515681830673e-06, 'Administration officials': 1.2632156341937778e-07, 'Aerosmith': 0.0883145200055968, 'Aetna': 0.0227757905278364, 'Afghanistan': 0.2434023123700171, 'Aftershock': 0.0002629962306256, 'Agatharchides': 9.236769066855744e-05, 'Ahmadinejad': 0.0262966543134163, "Ahmose-Henuttamehu's mummy": 3.696555452174507e-20, 'Aizutakada': 7.696360614662541e-09, 'Al Gore': 0.0823364404509695, 'Al-Dhahabi in his Talkhis al-Mustadrak': 1.612124610602195e-20, 'Alan Bean': 0.0135155081141698, 'Alan Cohn and Bobcat Goldthwait (the latter previously worked with Brown in Medusa: Dare to Be Truthful and Shakes the Clown)': 6.658189688457022e-56, 'Alang': 0.0002833598923389, 'Albany County Republican Chairman Joseph C. Frangella': 2.7614649397585014e-23, "Albert Finney in Sidney Lumet's crime drama": 6.083110945788356e-14, 'Alberta Party supporters': 1.2438530730669382e-11, 'Aleksandr M. Prokhorov Shared the Nobel Prize in Physics in 1964 for, respectively, semiconductor lasers and': 7.638246460514124e-28, 'Alex Webster': 3.993036761036937e-06, 'Alex Wharf': 5.298271200440658e-13, 'Algeria': 0.02069594237837, 'Ali Duba': 3.659973312667017e-12, 'Ali Hewson': 4.0904532440533566e-06, 'All of their friends': 1.5605360710592923e-06, 'All the players': 4.679819083762439e-06, 'All three men': 4.8643157130623055e-09, 'Amblypygids, particularly the species Phrynus marginemaculatus and Damon diadema': 1.6910954305683789e-37, 'American': 0.0476267485424613, 'American Gangster': 7.141527450130421e-05, 'American Sign Language, or ASL, for a time': 6.8879563 ...

# %%
import pickle

from scipy.stats import spearmanr, pearsonr, kendalltau

with open('/content/final_combined.pkl', 'rb') as f:  # Replace 'your_pickle_file.pkl' with your pickle file path
    phrase_counter = pickle.load(f)

book_corpus_entities = dict(phrase_counter)

# Step 3: Map the occurrences from the pickle data to the "Entity" column in the DataFrame
# We assume the 'phrase_counter' is a dictionary where the keys are phrases (same as 'Entity' column)
# and the values are their respective counts (or occurrence counts)
df['Book Corpus Count'] = df['Entity'].map(phrase_counter)

# Step 4: Handle missing data if any entities in the CSV don't exist in the phrase_counter
# For example, replace NaN values with 0 or another default value
df['Book Corpus Count'].fillna(0, inplace=True)

# Step 5: Calculate Spearman correlation between the 'API Response' and 'Phrase Count' columns
# Extract the 'API Response' and 'Phrase Count' columns as lists
api_response_values = df['average_probability']
phrase_count_values = df['Book Corpus Count']

spearman_corr, _ = spearmanr(api_response_values, phrase_count_values)
pearson_corr, _ = pearsonr(api_response_values, phrase_count_values)
kendall_corr, _ = kendalltau(api_response_values, phrase_count_values)

# Step 7: Print the correlation coefficients
print(f"Spearman correlation: {spearman_corr}")
print(f"Pearson correlation: {pearson_corr}")
print(f"Kendall correlation: {kendall_corr}")
# Out:
# Spearman correlation: 0.44949778835387105
# Pearson correlation: -0.002036866589801021
# Kendall correlation: 0.36206865099670005
# /tmp/ipython-input-3633331887.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Book Corpus Count'].fillna(0, inplace=True)

# %% [markdown]
# #Book Corpus vs API

# %%
import pandas as pd

# Read the CSV file into a pandas DataFrame
df = pd.read_csv('/content/entity_api_response_STRICT_UPTO_2024.csv')  # Replace 'your_file.csv' with your actual file path

# Convert the 'API Response' column to integers (assuming it's in string format)
#df['average_probability'] = df['average_probability'].apply(lambda x: int(x.strip(" '")) if x.strip(" '").isdigit() else None)
df['average_probability'] = df['average_probability'].astype(float)

# Create a dictionary with 'Entity' as keys and 'API Response' as values
entity_api_dict = pd.Series(df['average_probability'].values, index=df['Entity']).to_dict()

# Print the resulting dictionary
print(entity_api_dict)
# Out:
# {'corruption': 337000000.0, 'a man capable of being dangerous': 10.0, 'the beginning of this episode': 4490000.0, 'Pennsylvania, Michigan, Colorado, Ohio and New York': 5.0, 'defects': 346000000.0, 'Hypertensive crisis': 459000.0, 'the above picture': 1940000.0, 'suit': 969000000.0, "Ty Votaw, executive director of the IGF's Olympic Golf Committee, which has coordinated golf's Olympic bid": 0.0, 'the Khmer Rouge': 849000.0, 'four schools': 2690000.0, 'years': 9950000000.0, 'the Cleveland suburb of Kirtland': 54.0, 'This meeting': 24400000.0, 'classical physics': 1420000.0, 'The village': 193000000.0, 'public anger': 771000.0, 'the rise in rates': 279000.0, 'future issues': 5440000.0, 'the spinning rate of silk': 3.0, 'the measure': 105000000.0, 'classic, "This Time I Know It\'s For Real ", under the name Young Divas': 3.0, 'some corporate masseurs': 0.0, 'Caloundra in southern Queensland': 241.0, 'that work': 303000000.0, 'other rich countries': 66600.0, 'An older brother and sister': 474000.0, 'a Norwegian football (soccer) player': 7.0, 'a clear victory over the opposition Red-Green bloc': 0.0, 'several film festivals': 163000.0, 'private armies': 155000.0, 'Israeli and Egyptian offers': 0.0, 'the boys in Peter Pan': 5250.0, 'Vaishali around sizth century': 0.0, 'Oromiffa': 110000.0, 'Antwerpen': 13400000.0, 'a flight attendant': 9610000.0, 'his crew': 24200000.0, 'Egyptian natural gas': 48100.0, 'The prime minister and her new chancellor of the exchequer, the untested John Major': 0.0, 'the Siberian border where he had been jailed': 1.0, 'not an adequate strategic partner "': 198.0, 'a military official': 240000.0, 'Stefan': 189000000.0, 'the province': 119000000.0, 'natural gas as its raw material': 3160.0, 'High school and university education': 229000.0, 'Morgan Stanley': 23500000.0, 'the seeds': 86500000.0, 'The dollar': 43500000.0, 'The unions': 5160000.0, 'Binaural': 12100000.0, 'the bronze medal': 4950000.0, 'the term used within the European Union to encompass activities related to the achievement of an inclusive information society': 0.0, 'concrete reinforced with steel rebar': 7450.0, 'given potential changes to core market infrastructure': 1.0, 'the Thatcher government': 104000.0, 'You': 23430000000.0, 'USPS': 47500000.0, 'The explosion': 31000000.0, 'the achievements': 27400000.0, 'Jintara Poonlarp': 39800.0, 'his second wife': 8360000.0, 'The audience': 293000000.0, 'The Elwha Ecosystem Restoration project': 246.0, 'The personal income tax threshold': 13700.0, 'a new phase': 13500000.0, 'indexing': 163000000.0, 'Rostra': 356000.0, 'Eversel': 1880.0, 'place': 6520000000.0, 'the German, Italian, Japanese, and Portuguese communities': 2.0, 'any given time using the Contact Us form at the bottom of every page': 0.0, 'an entirely new type of television drama-contemporary realism': 1.0, 'Bill Laswell, another electronic adventurer': 1.0, 'noon': 185000000.0, 'the English language': 113000000.0, 'the Rafida': 2100.0, 'the last games of the second and third sets': 1.0, 'Li Yan': 1150000.0, 'Bradford': 114000000.0, 'TV processors': 3420.0, 'The show': 659000000.0, 'the gasoline, diesel, bitumen and other products': 1.0, 'The convoy of Qasim Fahim': 0.0, 'his future and the future of the country': 6.0, 'Beruni': 90400.0, 'the President of Poland and the Prime Minister of Poland': 4.0, 'the global automaker': 19200.0, 'Ethel Merman': 338000.0, 'a decade': 502000000.0, 'that distributor': 67600.0, 'AARP Insurance Plan American Association': 0.0, 'A six-month-old girl': 52300.0, 'a cross-strait taxation agreement': 0.0, 'advancing ones on the broad market': 0.0, 'Dave Albo': 4510.0, 'the Gandhi memorial': 62600.0, 'medicine': 2470000000.0, 'this problem': 382000000.0, 'Nell': 57800000.0, 'a new factory run by German carmaker Volkswagen in the town of Kaluga': 0.0, 'a pre-dawn attack': 12500.0, 'a tragic necessity': 5350.0, 'a decision': 337000000.0, 'electric power': 68500000.0, 'the Test series': 3710000.0, 'New Zealand v  ...

# %%
import pickle

from scipy.stats import spearmanr, pearsonr, kendalltau

with open('/content/final_combined.pkl', 'rb') as f:  # Replace 'your_pickle_file.pkl' with your pickle file path
    phrase_counter = pickle.load(f)

book_corpus_entities = dict(phrase_counter)

# Step 3: Map the occurrences from the pickle data to the "Entity" column in the DataFrame
# We assume the 'phrase_counter' is a dictionary where the keys are phrases (same as 'Entity' column)
# and the values are their respective counts (or occurrence counts)
df['Book Corpus Count'] = df['Entity'].map(phrase_counter)

# Step 4: Handle missing data if any entities in the CSV don't exist in the phrase_counter
# For example, replace NaN values with 0 or another default value
df['Book Corpus Count'].fillna(0, inplace=True)

# Step 5: Calculate Spearman correlation between the 'API Response' and 'Phrase Count' columns
# Extract the 'API Response' and 'Phrase Count' columns as lists
api_response_values = df['average_probability']
phrase_count_values = df['Book Corpus Count']

spearman_corr, _ = spearmanr(api_response_values, phrase_count_values)
pearson_corr, _ = pearsonr(api_response_values, phrase_count_values)
kendall_corr, _ = kendalltau(api_response_values, phrase_count_values)

# Step 7: Print the correlation coefficients
print(f"Spearman correlation: {spearman_corr}")
print(f"Pearson correlation: {pearson_corr}")
print(f"Kendall correlation: {kendall_corr}")
# Out:
# Spearman correlation: 0.5833686072719012
# Pearson correlation: 0.39864254880730376
# Kendall correlation: 0.48840915802659834
# /tmp/ipython-input-3633331887.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Book Corpus Count'].fillna(0, inplace=True)
